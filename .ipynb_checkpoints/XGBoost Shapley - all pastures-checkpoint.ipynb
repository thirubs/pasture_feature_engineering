# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
import warnings
warnings.filterwarnings("ignore")

# %%
#pip install shap

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
pasture_species = ['clover_rye_grass','phalaris','lucerne','improved_pasture','natural_grass']

# %%
pasture_type = 'phalaris'+'_data.csv' #select one from the pasture_species
df = pd.read_csv(pasture_type)
print(df.info())
# replace infinite values with NaN
df.replace([np.inf, -np.inf], np.nan, inplace=True)
y = df['FOO']
X = df.drop(['FOO'], axis=1)

# Create the training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#X_train_climate = X_train.drop(['ANIMAL_LOAD_DAYS','PERCENTAGE_OF_DAYS_GRAZED'], axis = 1)
#X_train_climate.drop(X_train_climate.filter(regex='vegetationclass|improvement|soilname').columns, axis=1, inplace=True)
#X_test_climate = X_test.drop(['ANIMAL_LOAD_DAYS','PERCENTAGE_OF_DAYS_GRAZED'], axis = 1)
#X_test_climate.drop(X_test_climate.filter(regex='vegetationclass|improvement|soilname').columns, axis=1, inplace=True)
names = list(X_train.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8154 entries, 0 to 8153
# Data columns (total 89 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   3DAVG_RAIN         8154 non-null   float64
#  1   3DAVG_MAX_TEMP     8154 non-null   float64
#  2   3DAVG_MIN_TEMP     8154 non-null   float64
#  3   3DAVG_RH_TMAX      8154 non-null   float64
#  4   3DAVG_RH_TMIN      8154 non-null   float64
#  5   3DAVG_EVAP         8154 non-null   float64
#  6   3DAVG_RADIATION    8154 non-null   float64
#  7   3D_MIN_TEMP        8154 non-null   float64
#  8   3D_MAX_TEMP        8154 non-null   float64
#  9   5DAVG_RAIN         8154 non-null   float64
#  10  5DAVG_MAX_TEMP     8154 non-null   float64
#  11  5DAVG_MIN_TEMP     8154 non-null   float64
#  12  5DAVG_RH_TMAX      8154 non-null   float64
#  13  5DAVG_RH_TMIN      8154 non-null   float64
#  14  5DAVG_EVAP         8154 non-null   float64
# ...

# %%
xg_climate = xgb.XGBRegressor(objective='reg:squarederror', seed=42, n_estimators=20, max_depth=5, reg_lambda = 0)

# Fit the regressor to the training set
xg_climate.fit(X_train, y_train)

# Predict the labels of the test set: preds
preds_xg_climate = xg_climate.predict(X_test)
# compute the rmse: rmse
rmse_xg_climate = np.sqrt(mean_squared_error(y_test, preds_xg_climate))
print("\tRMSE: %0.2f" % (rmse_xg_climate))

# compute the mae: mae
mae_xg_climate = mean_absolute_error(y_test, preds_xg_climate)
print("\tMAE: %0.2f" % (mae_xg_climate))

#r2 score
print("\tR2 score:", round(r2_score(y_test,preds_xg_climate),2))
# Out:
# 	RMSE: 362.38
# 	MAE: 229.93
# 	R2 score: 0.86

# %%
explainer = shap.Explainer(xg_climate)
shap_values = explainer(X[:100])

# %%
from sklearn.ensemble import BaggingRegressor
print('Bootstrapped Aggregating (Bagging)')
base_esti = xgb.XGBRegressor(objective='reg:squarederror', seed=42, n_estimators=20, max_depth=5, reg_lambda = 0)
n_estis = 50
bagging_model = BaggingRegressor(estimator=base_esti, n_estimators=n_estis, random_state=42)
bagging_model.fit(X_train, y_train)
# Out:
# Bootstrapped Aggregating (Bagging)
# BaggingRegressor(estimator=XGBRegressor(base_score=None, booster=None,
#                                         callbacks=None, colsample_bylevel=None,
#                                         colsample_bynode=None,
#                                         colsample_bytree=None,
#                                         early_stopping_rounds=None,
#                                         enable_categorical=False,
#                                         eval_metric=None, feature_types=None,
#                                         gamma=None, gpu_id=None,
#                                         grow_policy=None, importance_type=None,
#                                         interaction_constraints=None,
#                                         learning_rate=None, max_bin=None,
#                                         max_cat_threshold=None,
#                                         max_cat_to_onehot=None,
# ...

# %%
background = X_train[:50]
explainer_bagging = shap.KernelExplainer(bagging_model.predict, background)
shap_values_bagging = explainer_bagging(X[:100])
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
from sklearn.ensemble import RandomForestRegressor
print('Random Forest')
# Instantiatethe XGBRegressor: xg_reg
rf_climate = RandomForestRegressor(max_depth=5, random_state = 5).fit(X_train, y_train)
# Out:
# Random Forest

# %%
explainer_rf = shap.Explainer(rf_climate)
shap_values_rf = explainer_rf(X[:100])

# %%
from sklearn.linear_model import LinearRegression
print('Linear Regression')
lr_climate = LinearRegression().fit(X_train, y_train)
explainer_lr = shap.Explainer(lr_climate.predict, X_train)
shap_values_lr = explainer_lr(X[:100])
# Out:
# Linear Regression

# %%
from sklearn.neural_network import MLPRegressor
dnn_climate = MLPRegressor(random_state=1, max_iter=1000, hidden_layer_sizes=(75,75)).fit(X_train, y_train)

# %%
#explainer_dnn = shap.Explainer(dnn_climate)

explainer_dnn = shap.KernelExplainer(dnn_climate.predict, background)
shap_values_dnn = explainer_dnn(X[:100])
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import StackingRegressor
base_models = [
    ('XGBoost', xgb.XGBRegressor(objective='reg:squarederror', seed=42, n_estimators=20, max_depth=5, reg_lambda = 0)),
    ('DNN', MLPRegressor(random_state=1, max_iter=1000, hidden_layer_sizes=(75,75)))
]
# Define the meta-model (final estimator)
meta_model = LinearRegression()
# Create the stacking model
stacking_regressor = StackingRegressor(estimators=base_models, final_estimator=meta_model)
# Train the stacking model
stacking_regressor.fit(X_train, y_train)
# Out:
# StackingRegressor(estimators=[('XGBoost',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=None,
#                                             gpu_id=None, grow_policy=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learnin...
# ...

# %%
explainer_stack_dnn = shap.KernelExplainer(stacking_regressor.predict, background)
shap_values_stack_dnn = explainer_stack_dnn(X[:100])
# Out:
# C:\Users\balasubt\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
#   0%|          | 0/100 [00:00<?, ?it/s]
# C:\Users\balasubt\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\balasubt\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\balasubt\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# ...

# %%
base_models_xr = [
    ('XGBoost', xgb.XGBRegressor(objective='reg:squarederror', seed=42, n_estimators=20, max_depth=5, reg_lambda = 0)),
    ('RF', RandomForestRegressor(max_depth=5, random_state = 5))
]
# Define the meta-model (final estimator)
meta_model_xr = MLPRegressor(random_state=1, max_iter=1000, hidden_layer_sizes=(75,75))
# Create the stacking model
stacking_regressor_xr = StackingRegressor(estimators=base_models_xr, final_estimator=meta_model_xr)
# Train the stacking model
stacking_regressor_xr.fit(X_train, y_train)
# Out:
# StackingRegressor(estimators=[('XGBoost',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=None,
#                                             gpu_id=None, grow_policy=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learnin...
# ...

# %%
explainer_stack_xr = shap.KernelExplainer(stacking_regressor_xr.predict, background)
shap_values_stack_xr = explainer_stack_xr(X[:100])
# Out:
# C:\Users\balasubt\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
#   0%|          | 0/100 [00:00<?, ?it/s]
# C:\Users\balasubt\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\balasubt\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\balasubt\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# ...

# %%
#Beeswarm plot
shap.plots.beeswarm(shap_values)

# %%
shap.plots.beeswarm(shap_values_bagging)

# %%
shap.plots.beeswarm(shap_values_rf)

# %%
shap.plots.beeswarm(shap_values_lr)

# %%
#Beeswarm plot
shap.plots.beeswarm(shap_values_dnn)

# %%
shap.plots.beeswarm(shap_values_stack_dnn)

# %%
shap.plots.beeswarm(shap_values_stack_xr)

# %%
np.shape(shap_values.values)
# Out:
# (315417, 88)

# %%
#waterfall plot
shap.plots.waterfall(shap_values[0])

# %%
low_v = 99
med_v = 43
high_v = 85

# %%
y.iloc[99]

print('Ground truth\n')
print('Low:', y.iloc[low_v])
print('Med:', y.iloc[med_v])
print('High:', y.iloc[high_v])
# Out:
# Ground truth
#
# Low: 144.0
# Med: 1244.0
# High: 3412.0

# %%
#force plot - low
shap.plots.force(shap_values[low_v])
# Out:
# <div id='iZMB01F0Z4QAC0JNBBAZW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
# Medium
shap.plots.force(shap_values[med_v])
# Out:
# <div id='iGEGMH36PJ4MGP9S7QP6A'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
# Large
shap.plots.force(shap_values[high_v])
# Out:
# <div id='i1VIPC5JM5P9WWCMSBZFU'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_bagging[low_v])
# Out:
# <div id='iB2S5RPDDEKZP3U035M2B'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_bagging[med_v])
# Out:
# <div id='iXAJK1253VOG4H6TODYGR'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_bagging[high_v])
# Out:
# <div id='iBGW6DZO8YD6ZW4G1021A'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_rf[low_v])
# Out:
# <div id='iFMAFEZQYCT84QQSZOHDX'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_rf[med_v])
# Out:
# <div id='i7F54ZOLK809E6OC8ATBK'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_rf[high_v])
# Out:
# <div id='iXRCRCBVAWWDZUDUPHT2H'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_lr[low_v])
# Out:
# <div id='iT2R6A68WAPYV2U69NK7C'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_lr[med_v])
# Out:
# <div id='iPSR0L09CLUOS6WZG9821'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_lr[high_v])
# Out:
# <div id='iNV00NGCHDD4JEQH1ID14'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_dnn[low_v])
# Out:
# <div id='iCART46CQR6HV3V0BRSDM'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_dnn[med_v])
# Out:
# <div id='iCOJBU7BM5BLQOSQ77106'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_dnn[high_v])
# Out:
# <div id='i42U9NH06O9125EXFDUMU'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_stack_dnn[low_v])
# Out:
# <div id='iDFUZEZY8963KAA7VTR2Y'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_stack_dnn[med_v])
# Out:
# <div id='iVEY6PMMOQWSOJ4FDCXJJ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_stack_dnn[high_v])
# Out:
# <div id='i67RC3HB54AV402T6O3L7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_stack_xr[low_v])
# Out:
# <div id='iVVBIFQMKEHSAWB19RLZ3'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_stack_xr[med_v])
# Out:
# <div id='iXJPZCMTLAHJLKO4Z939R'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.force(shap_values_stack_xr[high_v])
# Out:
# <div id='iNESCZHXGDU0I4KTCAHZV'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
#phalaris = [100,1000,700]
#lucerne = [659, 100, 8]
#clover = [659,100,199]
#natural = [599,100,688]
#for i in a:
#    shap.plots.force(shap_values[i], show=True)
#shap.plots.force(shap_values[1000])
#shap.plots.force(shap_values[700])

# %%
# Now let's see how the model uses "trends" in the prediction
#shap.plots.force(shap_values[0:100])

# %%
#feature importance
#shap.plots.bar(shap_values)

# %%
#feature importance
shap.plots.bar(shap_values)

# %%
shap.plots.bar(shap_values_bagging)

# %%
shap.plots.bar(shap_values_rf)

# %%
shap.plots.bar(shap_values_lr)

# %%
shap.plots.bar(shap_values_dnn)

# %%
shap.plots.bar(shap_values_stack_dnn)

# %%
shap.plots.bar(shap_values_stack_xr)
